# %% [markdown]
# #1. 사이킷런(Scikit-learn) 모듈
# * 대표적인 파이썬 머신러닝 모듈.
# * 다양한 머신러닝 알고리즘을 제공.
# * 다양한 샘플 데이터를 제공
# * 머신러닝 결과를 검증하는 기능 제공.
# * BSD 라이선스이므로 무료로 사용 및 배포가 가능
# * 공식 홈페이지: https://scikit-learn.org/stable/

# %% [markdown]
# #2. LienarSVC
# * 클래스를 구분으로 하는 분류 문제에서 각 클래스를 잘 구분하는 선을 그려주는 방식을 사용하는 알고리즘.
# * 지도학습 알고리즘을 사용하는 학습 전용 데이터와 결과 전용 데이터를 함께 갖고 있어야 사용이 가능한 알고리즘.

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

# %%
# 학습 데이터 준비
learn_data = [[0,0], [1,0], [0,1], [1,1]] # 독립변수
learn_label = [0,0,0,1] #종속변수

# %%
# 모델 객체 생성
svc = LinearSVC()

# %%
# 학습
svc.fit(learn_data, learn_label)
# Out:
# LinearSVC()

# %%
# 검증데이터 (= '시험볼 문제를 준비하겠다'는 의미)
test_data = [[0,0], [1,0], [0,1], [1,1]]

# %%
# 예측(='시험을 본다'는 의미)
test_label = svc.predict(test_data)

# %%
# 출력
test_label
# Out:
# array([0, 0, 0, 1])

# %%
# 예측 결과가 정답인지 확인
print(test_data, '의 예측결과:', test_label)
# Out:
# [[0, 0], [1, 0], [0, 1], [1, 1]] 의 예측결과: [0 0 0 1]

# %%
# 정답률 확인
print('정답률: ', accuracy_score([0,0,0,1], test_label))
# 정답률: 1.0 = 100%의 의미
# Out:
# 정답률:  1.0
